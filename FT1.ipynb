# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreekanth1512/CQF-project-file/blob/main/FT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas quantmod yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.1/447.1 kB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 115.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.66
#     Uninstalling yfinance-0.2.66:
#       Successfully uninstalled yfinance-0.2.66
# ...

# %%
import pandas as pd
import yfinance as yf
import numpy as np
from quantmod.markets import getData, getTicker

# %%
df1 = getData("AAPL", period= '5d')

# %%
df1
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2025-10-23  259.940002  260.619995  258.010010  259.579987  32754900
# 2025-10-24  261.190002  264.130005  259.179993  262.820007  38253700
# 2025-10-27  264.880005  269.119995  264.649994  268.809998  44888200
# 2025-10-28  268.989990  269.890015  268.149994  269.000000  41461500
# 2025-10-29  269.274994  271.410004  267.109985  270.540009  26944072
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Low'].plot(kind='hist', bins=20, title='Low')
# ...

# %%
df1 = getData("AAPL", period='ytd')

# %%
df1
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2025-01-02  248.049428  248.218840  240.964594  242.987411  55740700
# 2025-01-03  242.499146  243.316237  241.034344  242.499146  40244100
# 2025-01-06  243.445785  246.455106  242.339711  244.133347  45045600
# 2025-01-07  242.120476  244.681392  240.496252  241.353210  40856000
# 2025-01-08  241.064237  242.847913  239.200857  241.841476  37628900
# ...                ...         ...         ...         ...       ...
# 2025-10-23  259.940002  260.619995  258.010010  259.579987  32754900
# 2025-10-24  261.190002  264.130005  259.179993  262.820007  38253700
# 2025-10-27  264.880005  269.119995  264.649994  268.809998  44888200
# 2025-10-28  268.989990  269.890015  268.149994  269.000000  41461500
# 2025-10-29  269.274994  271.410004  267.109985  270.440002  27362987
#
# [207 rows x 5 columns]

# %%
df1.tail()
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2025-10-23  259.940002  260.619995  258.010010  259.579987  32754900
# 2025-10-24  261.190002  264.130005  259.179993  262.820007  38253700
# 2025-10-27  264.880005  269.119995  264.649994  268.809998  44888200
# 2025-10-28  268.989990  269.890015  268.149994  269.000000  41461500
# 2025-10-29  269.274994  271.410004  267.109985  270.440002  27362987

# %%
df1.head()
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2025-01-02  248.049428  248.218840  240.964594  242.987411  55740700
# 2025-01-03  242.499146  243.316237  241.034344  242.499146  40244100
# 2025-01-06  243.445785  246.455106  242.339711  244.133347  45045600
# 2025-01-07  242.120476  244.681392  240.496252  241.353210  40856000
# 2025-01-08  241.064237  242.847913  239.200857  241.841476  37628900

# %%
dow_stocks = ['AAPL', 'UNH', 'MSFT', 'HD', 'CAT', 'GS']
dow_stocks
# Out:
# ['AAPL', 'UNH', 'MSFT', 'HD', 'CAT', 'GS']

# %%
df2 = getData(dow_stocks, period='ytd')['Close']

# %%
df2
# Out:
# Ticker            AAPL         CAT          GS          HD        MSFT  \
# Date
# 2025-01-02  242.987411  354.417908  566.263977  381.462128  416.292511
# 2025-01-03  242.499161  358.378113  571.345886  382.169159  421.036469
# 2025-01-06  244.133347  358.782013  574.556519  382.355743  425.511871
# 2025-01-07  241.353226  357.599854  571.335999  377.308350  420.061798
# 2025-01-08  241.841492  355.698578  571.237549  380.224823  422.239838
# ...                ...         ...         ...         ...         ...
# 2025-10-23  259.579987  520.500000  750.780029  385.029999  520.559998
# 2025-10-24  262.820007  522.729980  783.880005  386.679993  523.609985
# 2025-10-27  268.809998  527.070007  789.989990  385.269989  531.520020
# 2025-10-28  269.000000  524.469971  792.090027  385.750000  542.070007
# 2025-10-29  270.385498  588.611023  789.375000  383.500000  539.640015
#
# Ticker             UNH
# Date
# 2025-01-02  495.694733
# 2025-01-03  504.036407
# 2025-01-06  504.694672
# ...

# %%
df2_mean = df2.mean()
df2_mean
# Out:
# Ticker
# AAPL    223.237759
# CAT     384.867837
# GS      651.082913
# HD      378.732143
# MSFT    457.820893
# UNH     388.446823
# dtype: float64

# %%
df2_corr = df2.corr()

# %%
df2_corr
# Out:
# Ticker      AAPL       CAT        GS        HD      MSFT       UNH
# Ticker
# AAPL    1.000000  0.677217  0.598798  0.706649  0.317346  0.108797
# CAT     0.677217  1.000000  0.915516  0.565857  0.843914 -0.472631
# GS      0.598798  0.915516  1.000000  0.659410  0.904274 -0.605219
# HD      0.706649  0.565857  0.659410  1.000000  0.424688 -0.057570
# MSFT    0.317346  0.843914  0.904274  0.424688  1.000000 -0.814364
# UNH     0.108797 -0.472631 -0.605219 -0.057570 -0.814364  1.000000

# %%
spy = getTicker('SPY')

# %%
spy.options
# Out:
# ('2025-10-29',
#  '2025-10-30',
#  '2025-10-31',
#  '2025-11-03',
#  '2025-11-04',
#  '2025-11-05',
#  '2025-11-06',
#  '2025-11-07',
#  '2025-11-14',
#  '2025-11-21',
#  '2025-11-28',
#  '2025-12-05',
#  '2025-12-19',
#  '2025-12-31',
#  '2026-01-16',
#  '2026-01-30',
#  '2026-02-20',
#  '2026-02-27',
#  '2026-03-20',
#  '2026-03-31',
#  '2026-06-18',
#  '2026-06-30',
#  '2026-09-18',
#  '2026-09-30',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17',
#  '2027-12-17',
#  '2028-01-21')

# %%
options = spy.option_chain('2026-03-31')
options
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPY260331C00345000 2025-09-10 17:50:57+00:00   345.0     313.37  313.50
# 1    SPY260331C00350000 2025-07-01 14:44:35+00:00   350.0     276.19  300.60
# 2    SPY260331C00355000 2025-10-06 15:46:17+00:00   355.0     323.00  337.00
# 3    SPY260331C00360000 2025-07-01 14:44:17+00:00   360.0     266.82  290.96
# 4    SPY260331C00365000 2025-06-05 13:33:57+00:00   365.0     241.90  266.76
# ..                  ...                       ...     ...        ...     ...
# 153  SPY260331C00780000 2025-10-29 15:06:48+00:00   780.0       2.80    2.75
# 154  SPY260331C00785000 2025-10-29 15:29:03+00:00   785.0       2.38    2.34
# 155  SPY260331C00790000 2025-10-29 18:08:27+00:00   790.0       2.02    2.00
# 156  SPY260331C00795000 2025-10-29 17:52:03+00:00   795.0       1.73    1.70
# 157  SPY260331C00800000 2025-10-29 18:05:17+00:00   800.0       1.46    1.45
#
# ...

# %%
df3 = options.calls[(options.calls['strike']>640)&(options.calls['strike']<700)]

df3.iloc[:,:7]
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 126  SPY260331C00645000 2025-10-29 15:10:25+00:00   645.0      65.91  65.35
# 127  SPY260331C00650000 2025-10-29 15:28:00+00:00   650.0      61.93  61.46
# 128  SPY260331C00655000 2025-10-29 13:52:59+00:00   655.0      58.95  57.50
# 129  SPY260331C00660000 2025-10-29 14:01:46+00:00   660.0      54.30  53.63
# 130  SPY260331C00665000 2025-10-29 16:03:12+00:00   665.0      49.83  49.80
# 131  SPY260331C00670000 2025-10-29 16:35:09+00:00   670.0      46.62  45.91
# 132  SPY260331C00675000 2025-10-29 15:28:00+00:00   675.0      43.00  42.45
# 133  SPY260331C00680000 2025-10-29 17:28:07+00:00   680.0      39.11  38.82
# 134  SPY260331C00685000 2025-10-29 16:58:33+00:00   685.0      36.23  35.43
# 135  SPY260331C00690000 2025-10-29 16:22:08+00:00   690.0      32.45  32.32
# 136  SPY260331C00695000 2025-10-29 13:56:13+00:00   695.0      30.35  29.37
#
#        ask    change
# 126  65.82  1.300003
# ...
